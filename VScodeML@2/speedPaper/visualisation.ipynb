# %%
import matplotlib.pyplot as plt
import numpy as np

# Normalization techniques
normalizations = [
    "StandardScaler", "MinMaxScaler", "MaxAbsScaler", "RobustScaler",
    "QuantileTransformer", "PowerTransformer"
]

# Strategies
strategies = ["Recursive", "Direct", "Hybrid"]

# R-squared data for Stock S&P500 multi-input 1 raw and 9 indicators
r_squared_multi_input = np.array([
    [0.731380, 0.228502, 0.950732],
    [0.747468, 0.267735, 0.973819],
    [0.777505, 0.259115, 0.966706],
    [0.722835, 0.215593, 0.975403],
    [0.710974, -8.621373, 0.978197],
    [0.722242, -2.22222, 0.978516]
])

# R-squared data for Stock S&P500 (Raw, DEMA, TEMA, WMA, SMA5)
r_squared_stock = np.array([
    [0.472590, 0.221720, 0.899402],
    [0.486810, 0.254533, 0.883808],
    [0.486810, 0.255473, 0.863890],
    [0.463377, 0.207809, 0.920052],
    [0.089826, -9.557117, 0.889073],
    [0.457552, -2.406046, 0.720053]
])

# Plotting the R-squared Comparison with separate lines for each normalization technique
plt.figure(figsize=(10, 6))

for i, normalization in enumerate(normalizations):
    plt.plot(strategies, r_squared_multi_input[i, :],
             marker='o', label=f'{normalization} - 1 raw & 9 indicator')
    plt.plot(strategies, r_squared_stock[i, :], marker='o',
             linestyle='dashed', label=f'{normalization} - 1 raw & 5 indicator')

plt.title('R-squared S&P500 Multi input (Recursive Strategy)')
plt.xlabel('Strategy')
plt.ylabel('R-squared')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Plotting the data with x-axis as normalization techniques and y-axis as strategies
for i, strategy in enumerate(strategies):
    plt.plot(normalizations,
             r_squared_multi_input[:, i], marker='o', label=f'{strategy} - Multi-input')
    plt.plot(normalizations, r_squared_stock[:, i], marker='o',
             linestyle='dashed', label=f'{strategy} - Stock')

plt.title('R-squared S&P500 Multi input (Recursive Strategy)')
plt.xlabel('Normalization')
plt.ylabel('R-squared')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Normalization techniques
normalizations = [
    "StandardScaler", "MinMaxScaler", "MaxAbsScaler", "RobustScaler",
    "QuantileTransformer", "PowerTransformer"
]

# Strategies
strategies = ["Recursive", "Direct", "Hybrid"]

# R-squared data for S&P500
r_squared_sp500_multi_input = np.array([
    [0.731380, 0.228502, 0.950732],
    [0.747468, 0.267735, 0.973819],
    [0.777505, 0.259115, 0.966706],
    [0.722835, 0.215593, 0.975403],
    [0.710974, -8.621373, 0.978197],
    [0.722242, -2.22222, 0.978516]
])

r_squared_sp500_stock = np.array([
    [0.472590, 0.221720, 0.899402],
    [0.486810, 0.254533, 0.883808],
    [0.486810, 0.255473, 0.863890],
    [0.463377, 0.207809, 0.920052],
    [0.089826, -9.557117, 0.889073],
    [0.457552, -2.406046, 0.720053]
])

# R-squared data for Nasdaq
r_squared_nasdaq_multi_input = np.array([
    [0.752658, 0.134505, 0.984943],
    [0.120929, 0.268335, 0.981434],
    [0.043026, 0.308015, 0.980278],
    [0.061352, 0.089754, 0.976522],
    [-1.761918, -9.557117, 0.978197],
    [-1.043353, -2.406046, 0.720053]
])

r_squared_nasdaq_stock = np.array([
    [0.492310, -0.034515, 0.965783],
    [0.063135, 0.078335, 0.973858],
    [0.075425, 0.067541, 0.952545],
    [-0.058325, -0.063895, 0.967823],
    [-1.681736, -8.621373, 0.978197],
    [-1.518365, -2.406046, 0.720053]
])

# Plotting R-squared values for both S&P500 and Nasdaq datasets

plt.figure(figsize=(10, 6))

# Plot S&P500 data
for i, strategy in enumerate(strategies):
    plt.plot(normalizations, r_squared_sp500_multi_input[:, i],
             marker='o', label=f'S&P500 {strategy} - 1 raw & 9 indicator')
    plt.plot(normalizations, r_squared_sp500_stock[:, i], marker='o',
             linestyle='dashed', label=f'S&P500 {strategy} - 1 raw & 4 indicator')

# Plot Nasdaq data
for i, strategy in enumerate(strategies):
    plt.plot(normalizations, r_squared_nasdaq_multi_input[:, i],
             marker='o', linestyle=':', label=f'Nasdaq {strategy} - 1 raw & 9 indicator')
    plt.plot(normalizations, r_squared_nasdaq_stock[:, i],
             marker='o', linestyle='-.', label=f'Nasdaq {strategy} - 1 raw & 4 indicator')

plt.title('R-squared Comparison for S&P500 and Nasdaq (Multi input)')
plt.xlabel('Normalization Technique')
plt.ylabel('R-squared')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Normalization techniques
normalizations = [
    "StandardScaler", "MinMaxScaler", "MaxAbsScaler", "RobustScaler",
    "QuantileTransformer", "PowerTransformer"
]

# Strategies
strategies = ["Recursive", "Direct", "Hybrid"]

# R-squared data for S&P500
r_squared_sp500_multi_input = np.array([
    [0.731380, 0.228502, 0.950732],
    [0.747468, 0.267735, 0.973819],
    [0.777505, 0.259115, 0.966706],
    [0.722835, 0.215593, 0.975403],
    [0.710974, -8.621373, 0.978197],
    [0.722242, -2.22222, 0.978516]
])

r_squared_sp500_stock = np.array([
    [0.472590, 0.221720, 0.899402],
    [0.486810, 0.254533, 0.883808],
    [0.486810, 0.255473, 0.863890],
    [0.463377, 0.207809, 0.920052],
    [0.089826, -9.557117, 0.889073],
    [0.457552, -2.406046, 0.720053]
])

# R-squared data for Nasdaq
r_squared_nasdaq_multi_input = np.array([
    [0.752658, 0.134505, 0.984943],
    [0.120929, 0.268335, 0.981434],
    [0.043026, 0.308015, 0.980278],
    [0.061352, 0.089754, 0.976522],
    [-1.761918, -9.557117, 0.978197],
    [-1.043353, -2.406046, 0.720053]
])

r_squared_nasdaq_stock = np.array([
    [0.492310, -0.034515, 0.965783],
    [0.063135, 0.078335, 0.973858],
    [0.075425, 0.067541, 0.952545],
    [-0.058325, -0.063895, 0.967823],
    [-1.681736, -8.621373, 0.978197],
    [-1.518365, -2.406046, 0.720053]
])

# MAE data for S&P500
mae_sp500_multi_input = np.array([
    [191.939583, 314.29382, 56.891775],
    [184.339081, 306.949944, 53.347172],
    [183.650083, 310.068499, 59.524850],
    [195.861800, 316.134753, 54.620186],
    [191.894301, 1217.95773, 49.519477],
    [193.871332, 626.486353, 48.384662]
])

mae_sp500_stock = np.array([
    [255.71054, 312.14929, 77.0589],
    [250.17932, 307.1817, 123.0003],
    [257.22677, 307.62772, 126.6471],
    [258.61142, 314.51593, 102.4056],
    [321.54425, 1400.6288, 137.2941],
    [258.80797, 795.6673, 188.8274]
])

# MAE data for Nasdaq
mae_nasdaq_multi_input = np.array([
    [956.814181, 1702.25019, 208.701826],
    [921.620876, 1802.406129, 258.098428],
    [921.424472, 1801.309623, 260.674744],
    [929.172505, 1689.533396, 260.957456],
    [921.429667, 2786.237832, 569.163284],
    [936.358, 2363.21843, 349.482706]
])

mae_nasdaq_stock = np.array([
    [1339.97234, 1851.01245, 300.204081],
    [1242.28121, 1916.29581, 331.248831],
    [1062.35026, 2198.94012, 330.476897],
    [1047.16156, 2307.7495, 393.348813],
    [3652.85094, 2437.81746, 452.137817],
    [4137.41897, 2798.3346, 515.848267]
])

# RMSE data for S&P500
rmse_sp500_multi_input = np.array([
    [229.362688, 384.028034, 71.489537],
    [222.268197, 371.191453, 71.606916],
    [221.338115, 373.905115, 80.750442],
    [239.657370, 387.003947, 68.916273],
    [234.561437, 1363.129427, 64.884148],
    [231.549494, 784.609267, 64.407717]
])

rmse_sp500_stock = np.array([
    [312.306846, 379.807357, 92.820035],
    [307.666293, 371.589333, 155.740555],
    [307.666293, 371.262993, 175.213035],
    [318.605740, 382.756414, 121.594007],
    [409.177562, 1400.628898, 137.294188],
    [316.782026, 795.667266, 227.533525]
])

# RMSE data for Nasdaq
rmse_nasdaq_multi_input = np.array([
    [1113.76132, 2033.208232, 273.485682],
    [1086.21272, 2189.91472, 302.358352],
    [1062.35026, 2189.308632, 305.319859],
    [1071.476156, 1947.046156, 330.578703],
    [2102.217391, 3652.85094, 373.882681],
    [1481.93624, 2593.21843, 415.382818]
])

rmse_nasdaq_stock = np.array([
    [1564.055182, 1861.01245, 300.204081],
    [1581.606872, 1905.29581, 348.658370],
    [1546.668327, 2198.94012, 406.872897],
    [1657.013433, 2307.7495, 476.815904],
    [2437.81746, 2784.456827, 518.424067],
    [2473.028742, 312.456827, 647.304839]
])

# MAPE data for S&P500
mape_sp500_multi_input = np.array([
    [0.040313, 0.069327, 0.013077],
    [0.041491, 0.068128, 0.012397],
    [0.041493, 0.068375, 0.013090],
    [0.045669, 0.069647, 0.012679],
    [0.042334, 0.269483, 0.011415],
    [0.043562, 0.134312, 0.011244]
])

mape_sp500_stock = np.array([
    [0.056877, 0.069220, 0.017594],
    [0.055827, 0.068692, 0.026785],
    [0.055827, 0.068437, 0.027226],
    [0.057386, 0.069596, 0.022737],
    [0.077596, 0.282391, 0.023870],
    [0.057349, 0.134957, 0.041106]
])

# MAPE data for Nasdaq
mape_nasdaq_multi_input = np.array([
    [0.065659, 0.128592, 0.017635],
    [0.070829, 0.126835, 0.014753],
    [0.070236, 0.138408, 0.023979],
    [0.070524, 0.114736, 0.016578],
    [0.163274, 0.356283, 0.029637],
    [0.143569, 0.308478, 0.048274]
])

mape_nasdaq_stock = np.array([
    [0.091227, 0.125692, 0.020685],
    [0.092135, 0.143525, 0.026903],
    [0.114328, 0.134548, 0.032768],
    [0.118435, 0.156883, 0.035682],
    [0.220371, 0.234589, 0.057846],
    [0.261879, 0.265243, 0.078297]
])

# Function to plot each metric


def plot_metric(metric_name, sp500_multi_input, sp500_stock, nasdaq_multi_input, nasdaq_stock):
    plt.figure(figsize=(10, 6))
    for i, strategy in enumerate(strategies):
        plt.plot(normalizations, sp500_multi_input[:, i], marker='o',
                 label=f'S&P500 {strategy} - 1 raw & 9 indicator')
        plt.plot(normalizations, sp500_stock[:, i], marker='o',
                 linestyle='dashed', label=f'S&P500 {strategy} - 1 raw & 4 indicator')
        plt.plot(normalizations, nasdaq_multi_input[:, i], marker='o',
                 linestyle=':', label=f'Nasdaq {strategy} - 1 raw & 9 indicator')
        plt.plot(normalizations, nasdaq_stock[:, i], marker='o',
                 linestyle='-.', label=f'Nasdaq {strategy} - 1 raw & 4 indicator')

    plt.title(
        f'{metric_name} Comparison for S&P500 and Nasdaq across Strategies')
    plt.xlabel('Normalization Technique')
    plt.ylabel(metric_name)
    if metric_name == 'R-squared':
        plt.legend(loc='lower left', frameon=False)
    else:
        plt.legend(loc='upper left', frameon=False)
    plt.grid(True)
    plt.show()


# Plot each metric
plot_metric('R-squared', r_squared_sp500_multi_input, r_squared_sp500_stock,
            r_squared_nasdaq_multi_input, r_squared_nasdaq_stock)
plot_metric('MAE', mae_sp500_multi_input, mae_sp500_stock,
            mae_nasdaq_multi_input, mae_nasdaq_stock)
plot_metric('RMSE', rmse_sp500_multi_input, rmse_sp500_stock,
            rmse_nasdaq_multi_input, rmse_nasdaq_stock)
plot_metric('MAPE', mape_sp500_multi_input, mape_sp500_stock,
            mape_nasdaq_multi_input, mape_nasdaq_stock)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for S&P500 DEMA (850 steps), S&P500 SMA_5, and S&P500 EMA_20
mae_snp_dema = np.array([
    # [329.98977, 325.75703, 89.295763],  # Not normalization
    [319.02967, 323.77489, 141.72496],  # StandardScaler
    [326.56062, 322.88607, 92.322819],  # MinMaxScaler
    [319.02967, 319.02967, 94.620625],  # MaxAbsScaler
    [329.98977, 319.02967, 111.2331],   # RobustScaler
    [321.54243, 1247.50754, 132.593471],  # QuantileTransformer
    [634.84089, 319.02967, 137.750519]  # PowerTransformer
])

mae_snp_sma5 = np.array([
    # [421.599750, 402.871646, 112.202746],  # Not normalization
    [319.02967, 311.486333, 99.747145],    # StandardScaler
    [414.737119, 319.02967, 118.099690],   # MinMaxScaler
    [319.02967, 388.427272, 100.745370],   # MaxAbsScaler
    [380.195772, 312.948209, 102.837534],  # RobustScaler
    [407.839292, 400.716925, 107.847443],  # QuantileTransformer
    [724.787787, 525.070820, 162.025074]   # PowerTransformer
])

mae_snp_ema20 = np.array([
    # [421.599750, 402.871646, 112.202746],  # Not normalization
    [319.02967, 311.486333, 99.747145],    # StandardScaler
    [414.737119, 319.02967, 118.099690],   # MinMaxScaler
    [319.02967, 388.427272, 100.745370],   # MaxAbsScaler
    [380.195772, 312.948209, 102.837534],  # RobustScaler
    [407.839292, 400.716925, 107.847443],  # QuantileTransformer
    [724.787787, 525.070820, 162.025074]   # PowerTransformer
])

# Data for Nasdaq DEMA, SMA_5, and EMA_20
mae_nasdaq_dema = np.array([
    # [1773.29777, 1588.82109, 380.374949],  # Not normalization
    [1773.29777, 1588.82109, 374.41524],   # StandardScaler
    [1773.29777, 1588.82109, 373.45615],   # MinMaxScaler
    [1773.29777, 1588.82109, 377.77882],   # MaxAbsScaler
    [1773.29777, 1588.82109, 373.2155],    # RobustScaler
    [1729.58731, 909.741789, 600.884185],  # QuantileTransformer
    [2631.85225, 609.821252, 1639.23245]   # PowerTransformer
])

mae_nasdaq_sma5 = np.array([
    # [1763.89781, 1715.46199, 366.702271],  # Not normalization
    [1763.89781, 1715.46199, 366.466762],  # StandardScaler
    [1763.89781, 1715.46199, 366.292504],  # MinMaxScaler
    [1763.89781, 1715.46199, 371.137387],  # MaxAbsScaler
    [1763.89781, 1715.46199, 366.327589],  # RobustScaler
    [1712.98731, 1756.697782, 2499.406012],  # QuantileTransformer
    [2499.406012, 1566.706489, 2482.687461]  # PowerTransformer
])

mae_nasdaq_ema20 = np.array([
    # [1725.081284, 1663.89781, 366.702271],  # Not normalization
    [1725.081284, 1663.89781, 366.466762],  # StandardScaler
    [1725.081284, 1663.89781, 366.292504],  # MinMaxScaler
    [1725.081284, 1663.89781, 371.137387],  # MaxAbsScaler
    [1725.081284, 1663.89781, 366.327589],  # RobustScaler
    [1712.98731, 1756.697782, 2499.406012],  # QuantileTransformer
    [2499.406012, 1566.706489, 2482.687461]  # PowerTransformer
])

# Normalization labels
normalizations = [
    "StandardScaler", "MinMaxScaler",
    "MaxAbsScaler", "RobustScaler", "QuantileTransformer", "PowerTransformer"
]

# Strategy labels
strategies = ["Recursive", "Direct", "Hybrid"]

# Plotting MAE for S&P500 and Nasdaq across Strategies and Normalization Techniques
plt.figure(figsize=(12, 8))

# S&P500 DEMA (850 steps)
for i in range(mae_snp_dema.shape[1]):
    plt.plot(normalizations, mae_snp_dema[:, i], marker='o',
             linestyle='-', label=f'S&P500 DEMA - {strategies[i]}')

# S&P500 SMA_5
for i in range(mae_snp_sma5.shape[1]):
    plt.plot(normalizations, mae_snp_sma5[:, i], marker='o',
             linestyle='--', label=f'S&P500 SMA_5 - {strategies[i]}')

# S&P500 EMA_20
for i in range(mae_snp_ema20.shape[1]):
    plt.plot(normalizations, mae_snp_ema20[:, i], marker='o',
             linestyle=':', label=f'S&P500 EMA_20 - {strategies[i]}')

# Nasdaq DEMA
for i in range(mae_nasdaq_dema.shape[1]):
    plt.plot(normalizations, mae_nasdaq_dema[:, i], marker='x',
             linestyle='-', label=f'Nasdaq DEMA - {strategies[i]}')

# Nasdaq SMA_5
for i in range(mae_nasdaq_sma5.shape[1]):
    plt.plot(normalizations, mae_nasdaq_sma5[:, i], marker='x',
             linestyle='--', label=f'Nasdaq SMA_5 - {strategies[i]}')

# Nasdaq EMA_20
for i in range(mae_nasdaq_ema20.shape[1]):
    plt.plot(normalizations, mae_nasdaq_ema20[:, i], marker='x',
             linestyle=':', label=f'Nasdaq EMA_20 - {strategies[i]}')

# Adding the legend with two columns
plt.legend(loc='upper center', bbox_to_anchor=(
    0.5, -0.15), ncol=2, fontsize='small')

plt.title("MAE Comparison for S&P500 and Nasdaq across Strategies")
plt.xlabel("Normalization Technique")
plt.ylabel("MAE")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
rmse_snp_dema = np.array([
    # [442.947476, 396.296972, 113.189961],  # Not normalization
    [388.427272, 388.427272, 117.190396],  # StandardScaler
    [419.265202, 417.056103, 157.002885],  # MinMaxScaler
    [388.427272, 388.427272, 123.125120],  # MaxAbsScaler
    [388.427272, 388.427272, 117.190396],  # RobustScaler
    [409.175622, 1247.50754, 137.750519],  # QuantileTransformer
    [634.84089, 319.02967, 137.750519]     # PowerTransformer
])
rmse_snp_sma5 = np.array([
    # [421.599750, 402.871646, 112.202746],  # Not normalization
    [319.02967, 311.486333, 99.747145],    # StandardScaler
    [414.737119, 319.02967, 118.099690],   # MinMaxScaler
    [319.02967, 388.427272, 100.745370],   # MaxAbsScaler
    [380.195772, 312.948209, 102.837534],  # RobustScaler
    [407.839292, 400.716925, 107.847443],  # QuantileTransformer
    [724.787787, 525.070820, 162.025074]   # PowerTransformer
])
rmse_snp_ema20 = np.array([
    # [421.599750, 402.871646, 112.202746],  # Not normalization
    [319.02967, 311.486333, 99.747145],    # StandardScaler
    [414.737119, 319.02967, 118.099690],   # MinMaxScaler
    [319.02967, 388.427272, 100.745370],   # MaxAbsScaler
    [380.195772, 312.948209, 102.837534],  # RobustScaler
    [407.839292, 400.716925, 107.847443],  # QuantileTransformer
    [724.787787, 525.070820, 162.025074]   # PowerTransformer
])
rmse_nasdaq_dema = np.array([
    # [2135.947476, 2006.296972, 1765.189961],  # Not normalization
    [1988.427272, 1988.427272, 1897.190396],  # StandardScaler
    [1919.265202, 1917.056103, 1957.002885],  # MinMaxScaler
    [1888.427272, 1888.427272, 1833.125120],  # MaxAbsScaler
    [1888.427272, 1888.427272, 1917.190396],  # RobustScaler
    [1809.175622, 1747.50754, 1737.750519],   # QuantileTransformer
    [1934.84089, 1819.02967, 1837.750519]     # PowerTransformer
])
rmse_nasdaq_sma5 = np.array([
    # [1763.89781, 1715.46199, 366.702271],  # Not normalization
    [1763.89781, 1715.46199, 366.466762],  # StandardScaler
    [1763.89781, 1715.46199, 366.292504],  # MinMaxScaler
    [1763.89781, 1715.46199, 371.137387],  # MaxAbsScaler
    [1763.89781, 1715.46199, 366.327589],  # RobustScaler
    [1712.98731, 1756.697782, 2499.406012],  # QuantileTransformer
    [2499.406012, 1566.706489, 2482.687461]  # PowerTransformer
])
rmse_nasdaq_ema20 = np.array([
    # [1725.081284, 1663.89781, 366.702271],  # Not normalization
    [1725.081284, 1663.89781, 366.466762],  # StandardScaler
    [1725.081284, 1663.89781, 366.292504],  # MinMaxScaler
    [1725.081284, 1663.89781, 371.137387],  # MaxAbsScaler
    [1725.081284, 1663.89781, 366.327589],  # RobustScaler
    [1712.98731, 1756.697782, 2499.406012],  # QuantileTransformer
    [2499.406012, 1566.706489, 2482.687461]  # PowerTransformer
])


# Plotting RMSE for S&P500 and Nasdaq across Strategies and Indicators
strategies = ["Recursive", "Direct", "Hybrid"]

# Plotting MAE for S&P500 and Nasdaq across Strategies and Normalization Techniques
plt.figure(figsize=(12, 8))

# S&P500 DEMA (850 steps)
for i in range(rmse_snp_dema.shape[1]):
    plt.plot(normalizations, rmse_snp_dema[:, i], marker='o',
             linestyle='-', label=f'S&P500 DEMA - {strategies[i]}')

# S&P500 SMA_5
for i in range(rmse_snp_sma5.shape[1]):
    plt.plot(normalizations, rmse_snp_sma5[:, i], marker='o',
             linestyle='--', label=f'S&P500 SMA_5 - {strategies[i]}')

# S&P500 EMA_20
for i in range(rmse_snp_ema20.shape[1]):
    plt.plot(normalizations, rmse_snp_ema20[:, i], marker='o',
             linestyle=':', label=f'S&P500 EMA_20 - {strategies[i]}')

# Nasdaq DEMA
for i in range(rmse_nasdaq_dema.shape[1]):
    plt.plot(normalizations, rmse_nasdaq_dema[:, i], marker='x',
             linestyle='-', label=f'Nasdaq DEMA - {strategies[i]}')

# Nasdaq SMA_5
for i in range(rmse_nasdaq_sma5.shape[1]):
    plt.plot(normalizations, rmse_nasdaq_sma5[:, i], marker='x',
             linestyle='--', label=f'Nasdaq SMA_5 - {strategies[i]}')

# Nasdaq EMA_20
for i in range(rmse_nasdaq_ema20.shape[1]):
    plt.plot(normalizations, rmse_nasdaq_ema20[:, i], marker='x',
             linestyle=':', label=f'Nasdaq EMA_20 - {strategies[i]}')

# Adding the legend with two columns
plt.legend(loc='upper center', bbox_to_anchor=(
    0.5, -0.15), ncol=2, fontsize='small')

plt.title("RMSE Comparison for S&P500 and Nasdaq across Strategies")
plt.xlabel("Normalization Technique")
plt.ylabel("RMSE")
plt.grid(True)
plt.tight_layout()
plt.show()

# Repeat the above for MAPE and R-squared using similar structures for data and plots

# %%
mape_snp_dema = np.array([
    # [0.072462, 0.071664, 0.020588],
    [0.071644, 0.070423, 0.031886],
    [0.071896, 0.070423, 0.021237],
    [0.071896, 0.070423, 0.021340],
    [0.071896, 0.070423, 0.025272],
    [0.071596, 0.277293, 0.029964],
    [0.072218, 0.136650, 0.030948]
])
mape_snp_sma5 = np.array([
    # [0.072080, 0.073166, 0.020847],
    [0.071479, 0.069001, 0.030826],
    [0.071443, 0.069087, 0.018592],
    [0.071443, 0.069087, 0.018972],
    [0.071479, 0.069087, 0.023209],
    [0.071360, 0.269595, 0.020932],
    [0.071804, 0.134051, 0.038267]
])
mape_snp_ema20 = np.array([
    # [0.070771, 0.069484, 0.018251],
    [0.070147, 0.068409, 0.028912],
    [0.070147, 0.068409, 0.016303],
    [0.070147, 0.068409, 0.016418],
    [0.070147, 0.068409, 0.018759],
    [0.069744, 0.271617, 0.024353],
    [0.070482, 0.135050, 0.036408]
])
mape_nasdaq_dema = np.array([
    # [0.119566, 0.119710, 0.027106],
    [0.119566, 0.119710, 0.026897],
    [0.119566, 0.119710, 0.027349],
    [0.119566, 0.11971, 0.027235],
    [0.119566, 0.119710, 0.026849],
    [0.118510, 0.194362, 0.041471],
    [0.118942, 0.163507, 0.042808]
])
mape_nasdaq_sma5 = np.array([
    # [0.118958, 0.113697, 0.025999],
    [0.118958, 0.113697, 0.030920],
    [0.118958, 0.113697, 0.026426],
    [0.118958, 0.113697, 0.026441],
    [0.118958, 0.113697, 0.027197],
    [0.117753, 0.174343, 0.031456],
    [0.118278, 0.150556, 0.042260]
])
mape_nasdaq_ema20 = np.array([
    # [0.116555, 0.122885, 0.022917],
    [0.116555, 0.122885, 0.025538],
    [0.116555, 0.122885, 0.022811],
    [0.116555, 0.122885, 0.023156],
    [0.116555, 0.122885, 0.024319],
    [0.116640, 0.178156, 0.036347],
    [0.115946, 0.156318, 0.053543]
])

# Strategy labels
strategies = ["Recursive", "Direct", "Hybrid"]

# Plotting MAE for S&P500 and Nasdaq across Strategies and Normalization Techniques
plt.figure(figsize=(12, 8))

# S&P500 DEMA (850 steps)
for i in range(mape_snp_dema.shape[1]):
    plt.plot(normalizations, mape_snp_dema[:, i], marker='o',
             linestyle='-', label=f'S&P500 DEMA - {strategies[i]}')

# S&P500 SMA_5
for i in range(mape_snp_sma5.shape[1]):
    plt.plot(normalizations, mape_snp_sma5[:, i], marker='o',
             linestyle='--', label=f'S&P500 SMA_5 - {strategies[i]}')

# S&P500 EMA_20
for i in range(mape_snp_ema20.shape[1]):
    plt.plot(normalizations, mape_snp_ema20[:, i], marker='o',
             linestyle=':', label=f'S&P500 EMA_20 - {strategies[i]}')

# Nasdaq DEMA
for i in range(mape_nasdaq_dema.shape[1]):
    plt.plot(normalizations, mape_nasdaq_dema[:, i], marker='x',
             linestyle='-', label=f'Nasdaq DEMA - {strategies[i]}')

# Nasdaq SMA_5
for i in range(mape_nasdaq_sma5.shape[1]):
    plt.plot(normalizations, mape_nasdaq_sma5[:, i], marker='x',
             linestyle='--', label=f'Nasdaq SMA_5 - {strategies[i]}')

# Nasdaq EMA_20
for i in range(mape_nasdaq_ema20.shape[1]):
    plt.plot(normalizations, mape_nasdaq_ema20[:, i], marker='x',
             linestyle=':', label=f'Nasdaq EMA_20 - {strategies[i]}')

# Adding the legend with two columns
plt.legend(loc='upper center', bbox_to_anchor=(
    0.5, -0.15), ncol=2, fontsize='small')

plt.title("MAPE Comparison for S&P500 and Nasdaq across Strategies")
plt.xlabel("Normalization Technique")
plt.ylabel("MAPE")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
r_square_snp_dema = np.array([
    # [0.052353, 0.175906, 0.932760],
    [0.051533, 0.185549, 0.855275],
    [0.050974, 0.185549, 0.927622],
    [0.050974, 0.185549, 0.927573],
    [0.050974, 0.185549, 0.904273],
    [0.096092, -9.300369, 0.866919],
    [0.029835, -2.323348, 0.861513]
])
r_square_snp_sma5 = np.array([
    # [0.051831, 0.108696, 0.932843],
    [0.051666, 0.212938, 0.863320],
    [0.051339, 0.211477, 0.942066],
    [0.051339, 0.211477, 0.940548],
    [0.051666, 0.211476, 0.918249],
    [0.092643, -9.001757, 0.929962],
    [0.030644, -2.274653, 0.796341]
])
r_square_snp_ema20 = np.array([
    # [0.052025, 0.168378, 0.947716],
    [0.050638, 0.177063, 0.872456],
    [0.050638, 0.177063, 0.954305],
    [0.050638, 0.177063, 0.953897],
    [0.050638, 0.177063, 0.943083],
    [0.105358, -9.562133, 0.906897],
    [0.029977, -2.430507, 0.808107]
])

r_square_nasdaq_dema = np.array([
    # [0.056435, 0.252049, 0.954826],
    [0.056435, 0.252049, 0.953811],
    [0.056435, 0.252049, 0.952842],
    [0.056435, 0.252049, 0.954843],
    [0.056435, 0.252049, 0.954037],
    [0.121619, -2.146642, 0.894115],
    [0.022648, -1.381465, 0.883167]
])
r_square_nasdaq_sma5 = np.array([
    # [0.055956, 0.305335, 0.958122],
    [0.055956, 0.305335, 0.940790],
    [0.055956, 0.305335, 0.956734],
    [0.055956, 0.305335, 0.957583],
    [0.055956, 0.305335, 0.955176],
    [0.118518, -1.739646, 0.938172],
    [0.023775, -1.117780, 0.884893]
])
r_square_nasdaq_ema20 = np.array([
    # [0.056206, 0.175371, 0.968563],
    [0.056206, 0.175371, 0.960416],
    [0.056206, 0.175371, 0.967927],
    [0.056206, 0.175371, 0.968045],
    [0.056206, 0.175371, 0.963147],
    [0.123020, -1.883956, 0.914246],
    [0.023559, -1.341503, 0.816142]
])
# Strategy labels
strategies = ["Recursive", "Direct", "Hybrid"]

# Plotting MAE for S&P500 and Nasdaq across Strategies and Normalization Techniques
plt.figure(figsize=(8, 8))

# S&P500 DEMA (850 steps)
for i in range(r_square_snp_dema.shape[1]):
    plt.plot(normalizations, r_square_snp_dema[:, i], marker='o',
             linestyle='-', label=f'S&P500 DEMA - {strategies[i]}')

# S&P500 SMA_5
for i in range(r_square_snp_sma5.shape[1]):
    plt.plot(normalizations, r_square_snp_sma5[:, i], marker='o',
             linestyle='--', label=f'S&P500 SMA_5 - {strategies[i]}')

# S&P500 EMA_20
for i in range(r_square_snp_ema20.shape[1]):
    plt.plot(normalizations, r_square_snp_ema20[:, i], marker='o',
             linestyle=':', label=f'S&P500 EMA_20 - {strategies[i]}')

# Nasdaq DEMA
for i in range(r_square_nasdaq_dema.shape[1]):
    plt.plot(normalizations, r_square_nasdaq_dema[:, i], marker='x',
             linestyle='-', label=f'Nasdaq DEMA - {strategies[i]}')

# Nasdaq SMA_5
for i in range(r_square_nasdaq_sma5.shape[1]):
    plt.plot(normalizations, r_square_nasdaq_sma5[:, i], marker='x',
             linestyle='--', label=f'Nasdaq SMA_5 - {strategies[i]}')

# Nasdaq EMA_20
for i in range(r_square_nasdaq_ema20.shape[1]):
    plt.plot(normalizations, r_square_nasdaq_ema20[:, i], marker='x',
             linestyle=':', label=f'Nasdaq EMA_20 - {strategies[i]}')

# Adding the legend with two columns
plt.legend(loc='upper center', bbox_to_anchor=(
    0.5, -0.15), ncol=2, fontsize='small')

plt.title("R_square Comparison for S&P500 and Nasdaq across Strategies")
plt.ylabel("R_square")
plt.grid(True)
plt.tight_layout()
plt.show()
